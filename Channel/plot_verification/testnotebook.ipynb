# %%
import matplotlib.pyplot as plt
import numpy as np
# filename='fig_'

# import os
# image_path = os.path.abspath(filename) # Figures out the absolute path for you in case your working directory moves around.
# type(image_path)

data=np.loadtxt(fname='t_=_0.01.csv',delimiter = ',')

# %% [markdown]
# D2Q17 couette transient

# %%
import matplotlib.pyplot as plt
import numpy as np
filename='fig_'

import os
image_path = os.path.abspath(filename) # Figures out the absolute path for you in case your working directory moves around.
type(image_path)

data=np.loadtxt(fname='t_=_0.01.csv',delimiter = ',')      	#exact
data1=np.loadtxt(fname='t_0.01_Re100.csv',delimiter=',')	#simulation
data2=np.loadtxt(fname='t_=_0.1.csv',delimiter=',')
data3=np.loadtxt(fname='t_0.1_Re100.csv',delimiter=',')
data4=np.loadtxt(fname='t_inf.csv',delimiter=',')
data5=np.loadtxt(fname='t_inf_21.csv',delimiter=',',skiprows = 1)


# data=np.loadtxt(fname='uxD2Q17couette.txt',delimiter = ',')
# data=np.loadtxt(fname='uxD2Q17couette.txt')
x=[]
y=[]

x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]

# z=[]

for i in range(len(data)):
		for j in range(4):
			if j==0:
				x.append(data[i][j])
			if j==1:
	 			y.append(data[i][j])
	 		# if j==2:
	 			# z.append(data[i][j])

for i in range(len(data1)):
		for j in range(4):
			if j==0:
				y1.append(data1[i][j])
			if j==2:
	 			x1.append(data1[i][j])

for i in range(len(data2)):
		for j in range(4):
			if j==0:
				x2.append(data2[i][j])
			if j==1:
	 			y2.append(data2[i][j])


for i in range(len(data3)):
		for j in range(4):
			if j==0:
				y3.append(data3[i][j])
			if j==2:
	 			x3.append(data3[i][j])

for i in range(len(data4)):
		for j in range(4):
			if j==0:
				x4.append(data4[i][j])
			if j==1:
	 			y4.append(data4[i][j])


for i in range(len(data5)):
		for j in range(4):
			if j==0:
				y5.append(data5[i][j])
			if j==2:
	 			x5.append(data5[i][j])




fig = plt.figure(figsize=(6,4))
ax1 = fig.add_axes([0,0,1,1])
ax1.scatter(x1,y1,label='RD2Q21',marker = '>',color='b')
ax1.plot(x,y,label='Exact',color='r')

ax1.scatter(x3,y3,marker = '>',color='b')
ax1.plot(x2,y2,color='r')

ax1.scatter(x5,y5,marker = '>',color='b')
ax1.plot(x4,y4,color='r')

plt.text(0.07,0.12,'t = 0.01',fontsize='10',bbox = dict(facecolor = 'white', alpha = 0.5))
plt.text(0.3,0.3,'t = 0.1',fontsize='10',bbox = dict(facecolor = 'white', alpha = 0.5))
plt.text(0.5,0.6,'t = $\infty$',fontsize='10',bbox = dict(facecolor = 'white', alpha = 0.5))



ax1.set_xlabel('y' )
ax1.set_ylabel( 'ux-Magnitude')
plt.title('D2Q21 Ux vsy couette')

# # ax1.scatter(x,y,marker='x',s=14)
# # ax1.scatter(x,z,marker='*',s=14)


# # ax1.scatter(x,y,marker='x',s=0.2,label='Forward')
# # ax1.scatter(x1,y1,s=0.4,marker='*',label='Kevrekidis Projective')


ax1.grid(alpha=0.5,lw=0.5,ls='--',color='tab:gray')
ax1.legend()
plt.savefig(image_path+' D2Q21 Ux vs y couette.pdf', format='pdf', bbox_inches='tight')

# %% [markdown]
# D2Q9

# %%
import matplotlib.pyplot as plt
import numpy as np
filename='fig_'

import os
image_path = os.path.abspath(filename) # Figures out the absolute path for you in case your working directory moves around.
type(image_path)

data=np.loadtxt(fname='uxD2Q9Couette.csv',delimiter = ',')

# data=np.loadtxt(fname='uxD2Q17couette.txt',delimiter = ',')
# data=np.loadtxt(fname='uxD2Q17couette.txt')
x=[]
y=[]
# z=[]

x.append(0)
y.append(0)

for i in range(len(data)):
		for j in range(4):
	 		if j==0:
	 			y.append(data[i][j])
	 		if j==2:
	 			x.append(data[i][j])
	 		# if j==2:
	 			# z.append(data[i][j])




x1 = np.linspace(0.0,2.5,11)
x2 = []

for i in range(len(x1)):
	x2.append(0.0114297*x1[i])

print(x1)
print(x2)


fig = plt.figure(figsize=(6,4))
ax1 = fig.add_axes([0,0,1,1])
ax1.plot(x,y,label='D2Q9')
ax1.plot(x1,x2,'bo',label = 'analytical')




ax1.set_xlabel('y')
ax1.set_ylabel( 'ux-Magnitude')
plt.title('D2Q9 Ux vs y couette')

# # ax1.scatter(x,y,marker='x',s=14)
# # ax1.scatter(x,z,marker='*',s=14)


# # ax1.scatter(x,y,marker='x',s=0.2,label='Forward')
# # ax1.scatter(x1,y1,s=0.4,marker='*',label='Kevrekidis Projective')


ax1.grid(alpha=0.5,lw=0.5,ls='--',color='tab:gray')
ax1.legend()
plt.savefig(image_path+' D2Q9 Ux vs ycouette.pdf', format='pdf', bbox_inches='tight')
# Out:
# [0.   0.25 0.5  0.75 1.   1.25 1.5  1.75 2.   2.25 2.5 ]
# [0.0, 0.002857425, 0.00571485, 0.008572274999999999, 0.0114297, 0.014287125, 0.017144549999999998, 0.020001974999999998, 0.0228594, 0.025716825, 0.02857425]
